# %% [markdown]
# ### Add scripts to the notebooks path

# %%
import os, sys

current_dir = os.getcwd()
print(current_dir)

# Get the parent directory
parent_dir = os.path.dirname(current_dir)

scripts_path = os.path.join(parent_dir, 'scripts')

# Insert the path to the parent directory
sys.path.insert(0, parent_dir)

# Insert the path to the Scripts directory
sys.path.insert(0, scripts_path)

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join('..')))
# Out:
# d:\KifiyaAIM-Course\Week - 11\GMF-Investments-Portfolio-Management\notebooks

# %% [markdown]
# ### Import Statements

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scripts.time_series_analyzer import TimeSeriesAnalyzer
from scripts.finance_data_processor import FinanceDataProcessor

# %%
sns.set_theme()

# %%
preprocessor = FinanceDataProcessor()
analyzer = TimeSeriesAnalyzer()

# %% [markdown]
# ### Load the data

# %%
tsla_data = preprocessor.read_data('TSLA')
bnd_data = preprocessor.read_data('BND')
spy_data = preprocessor.read_data('SPY')

# %% [markdown]
# ### Start of seasonal Analysis

# %%
# Create a dictionary holding all ticker data in a key value pair
data_dict = {
    'TSLA': tsla_data,  
    'BND': bnd_data,    
    'SPY': spy_data    
}

analyzer.analyze_trends_and_seasonality(data_dict)
# Out:
# ADF test p-value for TSLA: 0.5364410759806582
# TSLA series is non-stationary. Differencing the series.
# ADF test p-value after differencing for TSLA: 9.888461414177082e-18
# ADF test p-value for BND: 0.7785818429882192
# BND series is non-stationary. Differencing the series.
# ADF test p-value after differencing for BND: 4.3021035647404545e-26
# ADF test p-value for SPY: 0.2549961412191435
# SPY series is non-stationary. Differencing the series.
# ADF test p-value after differencing for SPY: 3.530074830709098e-18
